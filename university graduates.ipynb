# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as py

# %%
data = pd.read_csv("Nigerian_Graduates_Destination_Survey_(2013 -2017)_(Responses).csv")

# %%
data.head()
# Out:
#             Timestamp What is your gender  Year of graduation  \
# 0    2/8/2018 9:05:23                Male                2013
# 1  2/15/2018 12:11:32                Male                2014
# 2  2/15/2018 13:47:10              Female                2013
# 3  2/16/2018 13:01:34                Male                2017
# 4  2/16/2018 13:18:03              Female                2013
#
#                              Title of course studied  \
# 0                Electrical & Electronic Engineering
# 1                                         Psychology
# 2                                          Economics
# 3  Mass Communication (Communication and Language...
# 4                                         Statistics
#
#         Polytechnic/University attended  \
# 0    Obafemi Awolowo University,Ile-Ife
# 1    Obafemi Awolowo University,Ile-Ife
# 2  Bells University of Technology, Otta
# 3                 Bowen University, Iwo
# 4                Ekiti State University
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5219 entries, 0 to 5218
# Data columns (total 36 columns):
#  #   Column                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                        --------------  -----
#  0   Timestamp                                                                                                                     5219 non-null   object
#  1   What is your gender                                                                                                           5219 non-null   object
#  2   Year of graduation                                                                                                            5219 non-null   int64
# ...

# %% [markdown]
# 1,2,3,4,5,6,7,8,9,15,33

# %%
# create a list of the important features

columns = ["What is your gender","Year of graduation", "Title of course studied",
           "Polytechnic/University attended","What is your highest level of education?",
          "What best describes your current status?", "How many jobs have you had since graduation including your current one?",
          "Have you completed your NYSC?",
           "If you answered yes/ongoing to the previous question, what year did you (or will you) complete your NYSC?",
          "Did you need your higher education qualification to get your first job (the actual qualification, not the subject of study)?",
          "My course of study prepared me well for employment"]

# %%
new_data = data.loc[:, columns] #create the new dataframe with the important features

# %%
# new dataframe we're working with

new_data
# Out:
#      What is your gender  Year of graduation  \
# 0                   Male                2013
# 1                   Male                2014
# 2                 Female                2013
# 3                   Male                2017
# 4                 Female                2013
# ...                  ...                 ...
# 5214              Female                2014
# 5215              Female                2017
# 5216              Female                2014
# 5217              Female                2015
# 5218                Male                2016
#
#                                 Title of course studied  \
# 0                   Electrical & Electronic Engineering
# 1                                            Psychology
# 2                                             Economics
# 3     Mass Communication (Communication and Language...
# 4                                            Statistics
# ...                                                 ...
# ...

# %% [markdown]
# # data cleaning

# %%
new_data.describe(include = "all")
# Out:
#        What is your gender  Year of graduation Title of course studied  \
# count                 5219         5219.000000                    5219
# unique                   3                 NaN                     127
# top                   Male                 NaN        Computer Science
# freq                  2624                 NaN                     459
# mean                   NaN         2015.329182                     NaN
# std                    NaN            1.305153                     NaN
# min                    NaN         2013.000000                     NaN
# 25%                    NaN         2014.000000                     NaN
# 50%                    NaN         2015.000000                     NaN
# 75%                    NaN         2016.000000                     NaN
# max                    NaN         2017.000000                     NaN
#
#        Polytechnic/University attended  \
# count                             5219
# ...

# %% [markdown]
# ### gender column

# %%
new_data["What is your gender"].value_counts()  # 3 wrong data on the "gender" column
# Out:
# Male                 2624
# Female               2592
# Prefer not to say       3
# Name: What is your gender, dtype: int64

# %%
new_data["What is your gender"].isna().sum() #no missing values
# Out:
# 0

# %% [markdown]
# ### Year of graduation

# %%
new_data["Year of graduation"].value_counts() #no wrong data
# Out:
# 2015    1327
# 2017    1259
# 2016    1214
# 2014     824
# 2013     595
# Name: Year of graduation, dtype: int64

# %%
new_data["Year of graduation"].isna().sum()  #no missing value
# Out:
# 0

# %% [markdown]
# ### Title of course studied

# %%
new_data["Title of course studied"].value_counts()
# Out:
# Computer Science                                        459
# Accountancy                                             373
# Economics                                               321
# Electrical & Electronic Engineering                     214
# Mass Communication (Communication and Language Arts)    204
#                                                        ...
# Music                                                     1
# Department of Pharmacology and Toxicology                 1
# Child Dental Health                                       1
# Archeology and Tourism                                    1
# Igbo Linguistics                                          1
# Name: Title of course studied, Length: 127, dtype: int64

# %%
new_data["Title of course studied"].isna().sum()  #no missing value
# Out:
# 0

# %% [markdown]
# ### Polytechnic/University attended

# %%
new_data["Polytechnic/University attended"].unique()
# Out:
# array(['Obafemi Awolowo University,Ile-Ife',
#        'Bells University of Technology, Otta', 'Bowen University, Iwo',
#        'Ekiti State University', 'University of Benin',
#        'Covenant University Ota', 'University of Lagos',
#        'University of Ibadan', 'University of Port-Harcourt',
#        'Babcock University,Ilishan-Remo',
#        'Yaba College of Technology, Yaba, Lagos State.',
#        'University of Abuja, Gwagwalada',
#        'Federal University of Technology, Akure',
#        'Kwara State Polytechnic, Ilorin, Kwara State.',
#        'Crawford University Igbesa',
#        'Federal University of Technology, Minna.',
#        'Lagos State University Ojo, Lagos.',
#        'Heritage Polytechnic, Ikot Udota, Eket, Akwa Ibom State',
#        'Federal University, Oye-Ekiti, Ekiti State',
#        'University of Nigeria, Nsukka',
#        'Rivers State University of Science & Technology',
#        'Ambrose Alli University, Ekpoma,',
# ...
